# %%
import sys
import warnings
warnings.filterwarnings("ignore")
sys.path.append("../")
from lib.analyzers import IntraBivariateChbAnalyzer

# %% [markdown]
# ### Bar chart

# %%
analyzer = IntraBivariateChbAnalyzer("phase_lock_value")
analyzer.bivariate_zone_bar_chart("left", "unknown")

# %% [markdown]
# ### Distribution chart (kernel density estimation)

# %%
analyzer = IntraBivariateChbAnalyzer("phase_lock_value")
analyzer.bivariate_zone_dist_chart("left", "unknown")

# %% [markdown]
# ### Network plots average

# %%
analyzer = IntraBivariateChbAnalyzer("phase_lock_value")
analyzer.bivariate_network_plot_average("unknown", "delta")
# Out:
# 2025-03-23 23:50:12,393 - root - INFO - Seizure type = unknown
# 2025-03-23 23:50:24,893 - root - INFO - Seizure type = unknown
# 2025-03-23 23:50:37,367 - root - INFO - Seizure type = unknown
# 2025-03-23 23:50:49,959 - root - INFO - Seizure type = unknown
# 2025-03-23 23:51:02,759 - root - INFO - Seizure type = unknown
# 2025-03-23 23:51:15,054 - root - INFO - Seizure type = unknown
# 2025-03-23 23:51:27,106 - root - INFO - Seizure type = unknown
# 2025-03-23 23:51:39,388 - root - INFO - Seizure type = unknown
# 2025-03-23 23:51:51,633 - root - INFO - Seizure type = unknown
# 2025-03-23 23:52:04,558 - root - INFO - Seizure type = unknown
# 2025-03-23 23:52:15,490 - root - INFO - Seizure type = unknown

# %% [markdown]
# ### Network plots single event

# %%
analyzer = IntraBivariateChbAnalyzer("phase_lock_value")
analyzer.bivariate_network_plot_individual(5, "delta")
# Out:
# 2025-03-23 10:51:17,185 - root - INFO - Seizure type = nan
# 2025-03-23 10:51:17,402 - root - INFO - Seizure type = nan
# 2025-03-23 10:51:17,607 - root - INFO - Seizure type = nan
# 2025-03-23 10:51:17,786 - root - INFO - Seizure type = nan
# 2025-03-23 10:51:18,035 - root - INFO - Seizure type = nan
# 2025-03-23 10:51:18,253 - root - INFO - Seizure type = nan
# 2025-03-23 10:51:18,408 - root - INFO - Seizure type = nan
# 2025-03-23 10:51:18,575 - root - INFO - Seizure type = nan
# 2025-03-23 10:51:18,798 - root - INFO - Seizure type = nan
# 2025-03-23 10:51:18,988 - root - INFO - Seizure type = nan
# 2025-03-23 10:51:19,217 - root - INFO - Seizure type = nan
