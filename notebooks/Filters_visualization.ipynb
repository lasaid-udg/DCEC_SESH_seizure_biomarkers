# %%
import sys
import numpy
sys.path.append("../")
from lib.filters import FilterBank
from lib.visuals import plot_frequency_and_phase_response
# Out:
# /var/tmp/venv-project-1/lib/python3.11/site-packages/numpy/_core/getlimits.py:551: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)

# %% [markdown]
# ### Notch filter

# %%
SAMPLING_FREQUENCY = 256
POWER_LINE_FREQUENCY = 50

#########################################3

filter_bank = FilterBank(SAMPLING_FREQUENCY)
frequency_range, h = filter_bank.notch(POWER_LINE_FREQUENCY, get_freqz=True)

plot_frequency_and_phase_response(frequency_range, h)

#########################################
for idx in range(195, 205):
    ratio = numpy.abs(h[idx])
    gain = 20*numpy.log10(ratio)
    print(f"freq={frequency_range[idx]}Hz, \t ratio={ratio}, \t gain={gain}dB")
# Out:
# freq=48.75Hz, 	 ratio=0.7090617894999376, 	 gain=-2.986318352203283dB
# freq=49.0Hz, 	 ratio=0.6263356420759927, 	 gain=-4.06385747517095dB
# freq=49.25Hz, 	 ratio=0.5156724154730437, 	 gain=-5.752521988047644dB
# freq=49.50000000000001Hz, 	 ratio=0.37201192489625884, 	 gain=-8.588862770446129dB
# freq=49.75000000000001Hz, 	 ratio=0.19626672700106312, 	 gain=-14.1430663976728dB
# freq=50.0Hz, 	 ratio=2.0181489061661483e-15, 	 gain=-293.90093586267136dB
# freq=50.25Hz, 	 ratio=0.19585281984380817, 	 gain=-14.1614034239828dB
# freq=50.5Hz, 	 ratio=0.37060617576784, 	 gain=-8.621746957787266dB
# freq=50.75Hz, 	 ratio=0.5131802849892483, 	 gain=-5.7946007281263165dB
# freq=51.0Hz, 	 ratio=0.6229891650862449, 	 gain=-4.110390128908886dB

# %% [markdown]
# ### High pass butterworth

# %%
SAMPLING_FREQUENCY = 256
CUT_FREQUENCY = 0.5

#########################################

filter_bank = FilterBank(SAMPLING_FREQUENCY)
frequency_range, h = filter_bank.highpass_butter(CUT_FREQUENCY, get_freqz=True)

plot_frequency_and_phase_response(frequency_range[:20], h[:20])

#########################################
for idx in range(10):
    ratio = numpy.abs(h[idx])
    gain = 20*numpy.log10(ratio)
    angle = numpy.angle(h[idx])*180/numpy.pi
    print(f"freq={frequency_range[idx]}Hz, \t ratio={ratio}, \t gain={gain}dB, \t phase-shift={angle}°")
# Out:
# freq=0.0Hz, 	 ratio=4.974074724609358e-09, 	 gain=-166.0657538938197dB, 	 phase-shift=180.0°
# freq=0.25Hz, 	 ratio=0.06237593493529249, 	 gain=-24.099658636045874dB, 	 phase-shift=-77.96240842265638°
# freq=0.5Hz, 	 ratio=0.7071067747018213, 	 gain=-3.0103000362962633dB, 	 phase-shift=-179.99999999309244°
# freq=0.75Hz, 	 ratio=0.9810460522717225, 	 gain=-0.16621210972916545dB, 	 phase-shift=108.28835731957356°
# freq=1.0Hz, 	 ratio=0.9980531624462696, 	 gain=-0.0169264980573899dB, 	 phase-shift=77.95999643006178°
# freq=1.25Hz, 	 ratio=0.9996726538989671, 	 gain=-0.0028437575788984536dB, 	 phase-shift=61.36460552714261°
# freq=1.5Hz, 	 ratio=0.9999238622175239, 	 gain=-0.0006613495530377617dB, 	 phase-shift=50.72733354941614°
# freq=1.75Hz, 	 ratio=0.9999778221417595, 	 gain=-0.00019263656522715007dB, 	 phase-shift=43.280061928989284°
# freq=2.0Hz, 	 ratio=0.9999923822139747, 	 gain=-6.616750072753752e-05dB, 	 phase-shift=37.75938564098322°
# freq=2.25Hz, 	 ratio=0.9999970322711912, 	 gain=-2.5777403159232504e-05dB, 	 phase-shift=33.497267625138264°

# %% [markdown]
# ### Low pass butterworth

# %%
SAMPLING_FREQUENCY = 256
CUT_FREQUENCY = 80

#########################################

filter_bank = FilterBank(SAMPLING_FREQUENCY)
frequency_range, h = filter_bank.lowpass_butter(CUT_FREQUENCY, get_freqz=True)

plot_frequency_and_phase_response(frequency_range, h)

#########################################
for idx in range(312, 322):
    ratio = numpy.abs(h[idx])
    gain = 20*numpy.log10(ratio)
    print(f"freq={frequency_range[idx]}Hz, \t ratio={ratio}, \t gain={gain}dB")
# Out:
# freq=78.0Hz, 	 ratio=0.8079696981351411, 	 gain=-1.8520985315248537dB
# freq=78.25Hz, 	 ratio=0.7967844492942723, 	 gain=-1.9731830110544004dB
# freq=78.5Hz, 	 ratio=0.7851697429219545, 	 gain=-2.100728891965828dB
# freq=78.75Hz, 	 ratio=0.7731336869124165, 	 gain=-2.234908065530558dB
# freq=79.0Hz, 	 ratio=0.7606870939320493, 	 gain=-2.37587904131587dB
# freq=79.25Hz, 	 ratio=0.7478435113170182, 	 gain=-2.523785403182856dB
# freq=79.5Hz, 	 ratio=0.7346192099066305, 	 gain=-2.6787543853912172dB
# freq=79.75Hz, 	 ratio=0.7210331296701047, 	 gain=-2.8408956015237186dB
# freq=80.0Hz, 	 ratio=0.7071067811865481, 	 gain=-3.0102999566398045dB
# freq=80.25Hz, 	 ratio=0.6928641033534564, 	 gain=-3.1870387695607154dB
