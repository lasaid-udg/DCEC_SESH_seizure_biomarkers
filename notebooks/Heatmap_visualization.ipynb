# %%
import sys
sys.path.append("../")
from lib.analyzers import CirclizerCharts

# %%
circlizer = CirclizerCharts()
circlizer.windows_based_charts()

# %%
circlizer = CirclizerCharts()
circlizer.windows_based_heat_map()
