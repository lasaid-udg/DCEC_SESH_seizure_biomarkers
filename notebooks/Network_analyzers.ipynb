# %%
import sys
import warnings
warnings.filterwarnings("ignore")
sys.path.append("../")
from lib.analyzers import IntraBivariateChbAnalyzer, IntraBivariateSienaAnalyzer, IntraBivariateTuszAnalyzer

# %% [markdown]
# ### Scatter plot - all patients (CHB)

# %%
analyzer = IntraBivariateChbAnalyzer("global_efficiency_phase_lock_value_0_5")
analyzer.network_stripplot_chart("unknown")

# %% [markdown]
# ### Scatter plot - all patients (Siena)

# %%
analyzer = IntraBivariateSienaAnalyzer("global_efficiency_phase_lock_value_0_5")
analyzer.network_stripplot_chart("IAS")

# %% [markdown]
# ### Scatter plot - all patients (TUSZ)

# %%
analyzer = IntraBivariateTuszAnalyzer("global_efficiency_coherence_0_7")
analyzer.network_stripplot_chart("tnsz")

# %% [markdown]
# ### Line plot - single events (CHB)

# %%
analyzer = IntraBivariateChbAnalyzer("global_efficiency_coherence_0_3")
analyzer.network_lineplot_chart([49])

# %% [markdown]
# ### Line plot - single events (Siena)

# %%
analyzer = IntraBivariateSienaAnalyzer("global_efficiency_coherence_0_3")
analyzer.network_lineplot_chart([36])

# %% [markdown]
# ### Line plot - single events (Tusz)

# %%
analyzer = IntraBivariateTuszAnalyzer("global_efficiency_coherence_0_3")
analyzer.network_lineplot_chart([20])
