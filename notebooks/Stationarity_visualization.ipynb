# %%
import os
import sys
import warnings
warnings.filterwarnings("ignore")
sys.path.append("../")
from lib.stats import StationarityFile

# %% [markdown]
# ### CHB-MIT dataset

# %%
stationarity_results = StationarityFile("chb", [0.5, 1, 3, 5])
stationarity_results.bar_chart()

# %% [markdown]
# ### Siena dataset

# %%
OUTPUT_DIRECTORY = os.getenv("BIOMARKERS_PROJECT_HOME")
output_file_eeg = os.path.join(OUTPUT_DIRECTORY, "images", "siena", "stationarity_results.png")

stationarity_results = StationarityFile("siena", [0.5, 1, 3, 5])
stationarity_results.bar_chart(output_file_eeg)

# %% [markdown]
# ### Tusz dataset

# %%
stationarity_results = StationarityFile("tusz", [0.5, 1, 3, 5])
stationarity_results.bar_chart()
