# %%
import sys
import warnings
warnings.filterwarnings("ignore")
sys.path.append("../")
from lib.analyzers import IntraUnivariateChbAnalyzer

# %% [markdown]
# ### Bar chart

# %%
analyzer = IntraUnivariateChbAnalyzer("kurtosis")
analyzer.univariate_zone_bar_chart()

# %% [markdown]
# ### Distribution chart (kernel density estimation)

# %%
analyzer = IntraUnivariateChbAnalyzer("kurtosis")
analyzer.univariate_zone_dist_chart()

# %% [markdown]
# ### Topographic plots average

# %%
analyzer = IntraUnivariateChbAnalyzer("kurtosis")
analyzer.univariate_topo_plot_average("beta")

# %% [markdown]
# ### Topographic plots single event

# %%
analyzer = IntraUnivariateChbAnalyzer("power_spectral_density")
analyzer.univariate_topo_plot_individual(12, "theta")
