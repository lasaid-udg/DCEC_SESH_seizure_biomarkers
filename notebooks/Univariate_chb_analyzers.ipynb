# %%
import sys
import warnings
warnings.filterwarnings("ignore")
sys.path.append("../")
from lib.analyzers import IntraUnivariateChbAnalyzer

# %% [markdown]
# ### Bar chart

# %%
analyzer = IntraUnivariateChbAnalyzer("kurtosis")
analyzer.hemisfere_bar_chart("left", "unknown")

# %% [markdown]
# ### Distribution chart (kernel density estimation)

# %%
analyzer = IntraUnivariateChbAnalyzer("kurtosis")
analyzer.hemisfere_dist_chart("left", "unknown")

# %% [markdown]
# ### Topographic plots average

# %%
analyzer = IntraUnivariateChbAnalyzer("kurtosis")
analyzer.univariate_topo_plot_average("unknown", "beta")

# %% [markdown]
# ### Topographic plots single event

# %%
analyzer = IntraUnivariateChbAnalyzer("kurtosis")
analyzer.univariate_topo_plot_individual(12, "all")
# Out:
# 2025-03-16 16:39:59,238 - root - INFO - Seizure type = nan
# 2025-03-16 16:39:59,252 - root - INFO - Seizure type = nan
# 2025-03-16 16:39:59,289 - root - INFO - Seizure type = nan
# 2025-03-16 16:39:59,304 - root - INFO - Seizure type = nan
# 2025-03-16 16:39:59,320 - root - INFO - Seizure type = nan
# 2025-03-16 16:39:59,345 - root - INFO - Seizure type = nan
# 2025-03-16 16:39:59,364 - root - INFO - Seizure type = nan
# 2025-03-16 16:39:59,382 - root - INFO - Seizure type = nan
# 2025-03-16 16:39:59,403 - root - INFO - Seizure type = nan
# 2025-03-16 16:39:59,421 - root - INFO - Seizure type = nan
# 2025-03-16 16:39:59,440 - root - INFO - Seizure type = nan
