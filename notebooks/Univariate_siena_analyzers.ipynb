# %%
import sys
import warnings
warnings.filterwarnings("ignore")
sys.path.append("../")
from lib.analyzers import IntraUnivariateSienaAnalyzer, InterUnivariateSienaAnalyzer, MlUnivariateFeatureAnalyzer

# %% [markdown]
# ### Bar chart

# %%
analyzer = IntraUnivariateSienaAnalyzer("kurtosis")
analyzer.region_bar_chart("parietal", "IAS-T-Right")

# %% [markdown]
# ### Distribution chart (kernel density estimation)

# %%
analyzer = IntraUnivariateSienaAnalyzer("kurtosis")
analyzer.region_dist_chart("frontal", "IAS-T-Right")

# %% [markdown]
# ### Topographic plots average

# %%
analyzer = IntraUnivariateSienaAnalyzer("kurtosis")
analyzer.univariate_topo_plot_average("IAS-T-Right", "all")

# %% [markdown]
# ### Topographic plots single event

# %%
analyzer = IntraUnivariateSienaAnalyzer("kurtosis")
analyzer.univariate_topo_plot_individual(4, "all")
# Out:
# 2025-03-16 16:41:10,700 - root - INFO - Seizure type = IAS-T-Right
# 2025-03-16 16:41:10,707 - root - INFO - Seizure type = IAS-T-Right
# 2025-03-16 16:41:10,714 - root - INFO - Seizure type = IAS-T-Right
# 2025-03-16 16:41:10,720 - root - INFO - Seizure type = IAS-T-Right
# 2025-03-16 16:41:10,726 - root - INFO - Seizure type = IAS-T-Right
# 2025-03-16 16:41:10,733 - root - INFO - Seizure type = IAS-T-Right
# 2025-03-16 16:41:10,743 - root - INFO - Seizure type = IAS-T-Right
# 2025-03-16 16:41:10,749 - root - INFO - Seizure type = IAS-T-Right
# 2025-03-16 16:41:10,756 - root - INFO - Seizure type = IAS-T-Right
# 2025-03-16 16:41:10,762 - root - INFO - Seizure type = IAS-T-Right
# 2025-03-16 16:41:10,769 - root - INFO - Seizure type = IAS-T-Right

# %% [markdown]
# ## Bar chart (ictal vs preictal vs healthy)

# %%
analyzer = InterUnivariateSienaAnalyzer("kurtosis")
analyzer.univariate_zone_bar_chart("parietal")

# %% [markdown]
# ## Violin chart (ictal vs preictal vs healthy)

# %%
analyzer = InterUnivariateSienaAnalyzer("katz_fractal_dimension")
analyzer.univariate_zone_violin_chart("parietal")

# %% [markdown]
# ### Naive bayes comparion

# %%
ml_analyzer = MlUnivariateFeatureAnalyzer("siena", "kurtosis")
ml_analyzer.ml_bar_chart("IAS")
