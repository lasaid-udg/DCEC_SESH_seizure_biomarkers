# %%
import sys
import warnings
warnings.filterwarnings("ignore")
sys.path.append("../")
from lib.analyzers import IntraUnivariateSienaAnalyzer, InterUnivariateSienaAnalyzer

# %% [markdown]
# ### Bar chart

# %%
analyzer = IntraUnivariateSienaAnalyzer("kurtosis")
analyzer.univariate_zone_bar_chart()

# %% [markdown]
# ### Distribution chart (kernel density estimation)

# %%
analyzer = IntraUnivariateSienaAnalyzer("kurtosis")
analyzer.univariate_zone_dist_chart()

# %% [markdown]
# ### Topographic plots average

# %%
analyzer = IntraUnivariateSienaAnalyzer("kurtosis")
analyzer.univariate_topo_plot_average("all")

# %% [markdown]
# ### Topographic plots single event

# %%
analyzer = IntraUnivariateSienaAnalyzer("power_spectral_density")
analyzer.univariate_topo_plot_individual(4, "delta")

# %% [markdown]
# ## Bar chart (ictal vs preictal vs healthy)

# %%
analyzer = InterUnivariateSienaAnalyzer("kurtosis")
analyzer.univariate_zone_bar_chart()

# %% [markdown]
# ## Violin chart (ictal vs preictal vs healthy)

# %%
analyzer = InterUnivariateSienaAnalyzer("katz_fractal_dimension")
analyzer.univariate_zone_violin_chart()
