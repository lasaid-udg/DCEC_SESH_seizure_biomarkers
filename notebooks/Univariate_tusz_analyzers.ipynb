# %%
import sys
import warnings
warnings.filterwarnings("ignore")
sys.path.append("../")
from lib.analyzers import IntraUnivariateTuszAnalyzer, InterUnivariateTuszAnalyzer

# %% [markdown]
# ### Bar chart

# %%
analyzer = IntraUnivariateTuszAnalyzer("kurtosis")
analyzer.region_bar_chart("parietal", "absz")

# %% [markdown]
# ### Distribution chart (kernel density estimation)

# %%
analyzer = IntraUnivariateTuszAnalyzer("kurtosis")
analyzer.region_dist_chart("parietal", "absz")

# %% [markdown]
# ### Topographic plots

# %%
analyzer = IntraUnivariateTuszAnalyzer("kurtosis")
analyzer.univariate_topo_plot_average("absz", "beta")

# %%
analyzer = IntraUnivariateTuszAnalyzer("kurtosis")
analyzer.univariate_topo_plot_individual(31, "beta")
# Out:
# 2025-03-16 16:42:16,193 - root - INFO - Seizure type = absz
# 2025-03-16 16:42:16,255 - root - INFO - Seizure type = absz
# 2025-03-16 16:42:16,297 - root - INFO - Seizure type = absz
# 2025-03-16 16:42:16,349 - root - INFO - Seizure type = absz
# 2025-03-16 16:42:16,402 - root - INFO - Seizure type = absz
# 2025-03-16 16:42:16,453 - root - INFO - Seizure type = absz
# 2025-03-16 16:42:16,494 - root - INFO - Seizure type = absz
# 2025-03-16 16:42:16,534 - root - INFO - Seizure type = absz
# 2025-03-16 16:42:16,593 - root - INFO - Seizure type = absz
# 2025-03-16 16:42:16,642 - root - INFO - Seizure type = absz
# 2025-03-16 16:42:16,687 - root - INFO - Seizure type = absz

# %% [markdown]
# ## Bar chart (ictal vs preictal vs healthy)

# %%
analyzer = InterUnivariateTuszAnalyzer("kurtosis")
analyzer.univariate_zone_bar_chart("parietal")

# %% [markdown]
# ## Violin chart (ictal vs preictal vs healthy)

# %%
analyzer = InterUnivariateTuszAnalyzer("kurtosis")
analyzer.univariate_zone_violin_chart("parietal")
